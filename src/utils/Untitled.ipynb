# %%
# %load /root/data_lxj/UniMSE/PreProcessMOS.py
import pickle
import numpy as np
import random
def to_pickle(obj, path):
    with open(path, 'wb') as f:
        pickle.dump(obj, f)
with open('/root/data_lxj/UniMSE/datasets/MOS/mosei_dev.pkl', 'rb') as file:
    # 加载pkl文件中的对象
    mosei_data = pickle.load(file)
with open('/root/data_lxj/UniMSE/datasets/MOS/mosi_dev.pkl', 'rb') as file:
    # 加载pkl文件中的对象
    mosi_data = pickle.load(file)

    
print(len(mosei_data),len(mosi_data))    
data=mosei_data+mosi_data
print(len(data))
# for i in range(len(data)):
#     sample=data[i]
#     if i < 10:print(sample)
    
#     sample=(sample[0],float(sample[1]),sample[2])
    
#     if i < 10:
#         print(sample)
#         print()
#     data[i]=sample

# print(data)

for i in range(10):
    random.shuffle(data)
print(data[:10])
to_pickle(data,'/root/data_lxj/UniMSE/datasets/MOS/mos_dev.pkl')
# Out:
# 1871 229
# 2100
# [(([], array([[ 0.26734462,  0.47300625,  0.44426256, ..., -0.7902392 ,
#         -0.7548996 ,  0.39024103],
#        [ 0.26719505,  0.47257167,  0.44383237, ..., -0.7902504 ,
#         -0.7544899 ,  0.3904457 ],
#        [ 0.26732332,  0.47372842,  0.44466126, ..., -0.7913767 ,
#         -0.7544056 ,  0.39028358],
#        ...,
#        [ 0.2653912 ,  0.47040075,  0.44616565, ..., -0.7928166 ,
#         -0.75630355,  0.3936536 ],
#        [ 0.26529753,  0.46994022,  0.4463063 , ..., -0.7926346 ,
#         -0.7561338 ,  0.39327782],
#        [ 0.26507255,  0.46954727,  0.44665784, ..., -0.7926503 ,
#         -0.75617516,  0.39354444]], dtype=float32), array([[ 0.00523847,  0.08045461,  0.15229933, ..., -1.13585997,
#         -1.28288066, -1.29924083],
#        [ 0.13403654,  0.49599606,  1.31496394, ..., -1.09798658,
#         -1.0598228 , -0.69918954],
#        [ 0.34151134,  0.98907733,  1.12240207, ..., -1.89503837,
#         -1.98070133, -1.87363946],
# ...
